# %%
import pandas as pd

# %%
data = {
        'Name': ['Mr. Owen Harris Braund', 'Mrs. John Bradley (Florence Briggs Thayer) Cumings', 'Miss. Laina Heikkinen', 'Mrs. Jacques Heath (Lily May Peel) Futrelle', 'Mr. William Henry Allen', 'Mr. James Moran', 'Mr. Timothy J McCarthy', 'Master. Gosta Leonard Palsson', 'Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson', 'Mr. Anders Johan Andersson'],
    'Passenger_id': [12, 24, 435, 34, 23, 24, 45, 56, 78, 21],
    'Age': [22, 38, 26, 35, 35, 27, 54, 72, 27, 14],
    'cabin': ['C85', 'C123', 'E46', 'E46', 'E46', 'E46', 'E46', 'E46', 'E46', 'E46'],
    "male": [True, False, False, False, True, True, True, True, False, True],
    'dead': [False, False, True, False, True, True, True, True, False, False]
}
df_titanic = pd.DataFrame(data)
df_titanic
# Out:
#                                                 Name  Passenger_id  Age cabin  \
# 0                             Mr. Owen Harris Braund            12   22   C85
# 1  Mrs. John Bradley (Florence Briggs Thayer) Cum...            24   38  C123
# 2                              Miss. Laina Heikkinen           435   26   E46
# 3        Mrs. Jacques Heath (Lily May Peel) Futrelle            34   35   E46
# 4                            Mr. William Henry Allen            23   35   E46
# 5                                    Mr. James Moran            24   27   E46
# 6                             Mr. Timothy J McCarthy            45   54   E46
# 7                      Master. Gosta Leonard Palsson            56   72   E46
# 8   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson            78   27   E46
# 9                         Mr. Anders Johan Andersson            21   14   E46
#
#     male   dead
# 0   True  False
# 1  False  False
# 2  False   True
# 3  False  False
# 4   True   True
# ...

# %%
df_titanic["Age"].max()
# Out:
# 72

# %%
if df_titanic["Age"].max() == 72:
    print(df_titanic["Name"])
# Out:
# 0                               Mr. Owen Harris Braund
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2                                Miss. Laina Heikkinen
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4                              Mr. William Henry Allen
# 5                                      Mr. James Moran
# 6                               Mr. Timothy J McCarthy
# 7                        Master. Gosta Leonard Palsson
# 8     Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9                           Mr. Anders Johan Andersson
# Name: Name, dtype: object

# %%
cities = {
    'name': ['Paris', 'Ankara', 'London', 'Rome', 'Vienna', 'Cophenagen'],
    'latitude': [48.8566, 39.9334, 51.5074, 41.9028, 48.2082, 55.6761],
    'longitude': [2.3522, 32.8597, 0.1278, 12.4964, 16.3738, 12.5683],
    'population': [2206488, 5445026, 8982000, 2872800, 1897491, 1330993],
    'area_km2': [105.4, 24521, 1572, 1285, 414.6, 179.8]
}

df_cities = pd.DataFrame(cities)
df_cities
# Out:
#          name  latitude  longitude  population  area_km2
# 0       Paris   48.8566     2.3522     2206488     105.4
# 1      Ankara   39.9334    32.8597     5445026   24521.0
# 2      London   51.5074     0.1278     8982000    1572.0
# 3        Rome   41.9028    12.4964     2872800    1285.0
# 4      Vienna   48.2082    16.3738     1897491     414.6
# 5  Cophenagen   55.6761    12.5683     1330993     179.8

# %%
df_cities["name"]
# Out:
# 0         Paris
# 1        Ankara
# 2        London
# 3          Rome
# 4        Vienna
# 5    Cophenagen
# Name: name, dtype: object

# %%
df_cities.describe()
# Out:
#         latitude  longitude    population      area_km2
# count   6.000000   6.000000  6.000000e+00      6.000000
# mean   47.680750  12.796367  3.789133e+06   4679.633333
# std     5.892976  11.705132  2.921405e+06   9738.823045
# min    39.933400   0.127800  1.330993e+06    105.400000
# 25%    43.479150   4.888250  1.974740e+06    238.500000
# 50%    48.532400  12.532350  2.539644e+06    849.800000
# 75%    50.844700  15.422425  4.801970e+06   1500.250000
# max    55.676100  32.859700  8.982000e+06  24521.000000

# %%
titanic = pd.read_csv("C:/Users/burka/Desktop/sınav/titanic (4).xls")

# %%
print(titanic.shape)
# Out:
# (891, 12)

# %%
print(titanic.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.head()   #ilk 5 satırı getirir
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()   #son 5 satırı getirir
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/58/d9/796181a30827b12101786c21301f0f4536597a9249530916b1fdb5bbad91/openpyxl-3.1.3-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/96/c2/3dd434b0108730014f1b96fd286040dc3bcb70066346f7e01ec2ac95865f/et_xmlfile-1.1.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/251.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/251.3 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/251.3 kB 445.2 kB/s eta 0:00:01
#    ----------- --------------------------- 71.7/251.3 kB 491.5 kB/s eta 0:00:01
#    ------------------ ------------------- 122.9/251.3 kB 722.1 kB/s eta 0:00:01
# ...

# %%
titanic.to_excel("titanicdata.xlsx", sheet_name="passengers", index=False)  #excele cevırme
titanic = pd.read_excel("titanicdata.xlsx", sheet_name="passengers")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
ages = titanic["Age"]
ages
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages.shape
# Out:
# (891,)

# %%
titanic[["Age", "Pclass"]]
# Out:
#       Age  Pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
titanic[['Age', 'Pclass']].shape #icerdekı bılgı sayısı arttıkca koselı parantez sayısıda artıyor
# Out:
# (891, 2)

# %%
# extract age above 35  # 35'in üzerindeki yaşları çıkar
a = titanic["Age"] > 35
titanic[a]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
b = titanic["Pclass"].isin([2,3])  #sadece pclass 2 ve 3 olanları caırmak ıcın ısın kullanılır 
titanic[b]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
age_no_na = titanic[titanic["Age"].notna()]  #age sutunundakı bos(null) degerlerı cıkarmak ıcın notna kullanılır
age_no_na
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
adult_names = titanic.loc[titanic["Age"] > 35, "Name"]  #35 yaşından büyük olan yolcuların isimlerini getirir
adult_names
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 13                           Andersson, Mr. Anders Johan
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 865                             Bystrom, Mrs. (Karolina)
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885                 Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 217, dtype: object

# %%
# 10'dan 25'e kadar olan satırlar ve 3'ten 5'e kadar olan sütunlarla ilgileniyorum.
titanic.iloc[9:25, 2:5]  #9 dahil 25 dahil degıl 2 dahil 5 dahil degıl
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                               Rice, Master. Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %%
titanic.iloc[0:3, 3] = "Anonnymous"  #0 dahil 3 dahil degıl 3. sutun

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                      Anonnymous    male  22.0      1      0
# 1                                      Anonnymous  female  38.0      1      0
# 2                                      Anonnymous  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# ...

# %% [markdown]
# Pandas Plot

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
path = "https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2.csv"

air_quality = pd.read_csv(path, index_col=0, parse_dates=True) #index zaman olacaksa parse_dates kullancaz
air_quality
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %%
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1035 entries, 2019-05-07 02:00:00 to 2019-06-21 02:00:00
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   station_antwerp  95 non-null     float64
#  1   station_paris    1004 non-null   float64
#  2   station_london   969 non-null    float64
# dtypes: float64(3)
# memory usage: 32.3 KB

# %%
air_quality.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
air_quality["station_paris"].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True) #subplots komutu alt alta ayrı olcumu gösterıyor
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_cities
# Out:
#          name  latitude  longitude  population  area_km2
# 0       Paris   48.8566     2.3522     2206488     105.4
# 1      Ankara   39.9334    32.8597     5445026   24521.0
# 2      London   51.5074     0.1278     8982000    1572.0
# 3        Rome   41.9028    12.4964     2872800    1285.0
# 4      Vienna   48.2082    16.3738     1897491     414.6
# 5  Cophenagen   55.6761    12.5683     1330993     179.8

# %%
df_cities["pop_density"] = df_cities["population"] / df_cities["area_km2"]  #yeni sutun olusturmak ıcın
df_cities
# Out:
#          name  latitude  longitude  population  area_km2   pop_density
# 0       Paris   48.8566     2.3522     2206488     105.4  20934.421252
# 1      Ankara   39.9334    32.8597     5445026   24521.0    222.055626
# 2      London   51.5074     0.1278     8982000    1572.0   5713.740458
# 3        Rome   41.9028    12.4964     2872800    1285.0   2235.642023
# 4      Vienna   48.2082    16.3738     1897491     414.6   4576.678726
# 5  Cophenagen   55.6761    12.5683     1330993     179.8   7402.630701

# %% [markdown]
# devamında great circle haversine formulu vaar gereklı olursa bak
